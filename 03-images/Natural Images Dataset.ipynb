# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import helper_functions as hp

from pathlib import Path

from skimage.io import imread
from skimage.color import rgb2gray
from skimage.transform import rescale

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPool2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Natural Images
#
# https://www.kaggle.com/datasets/prasunroy/natural-images

# %% [markdown]
# ### Read file names and classes

# %%
DESKTOP = Path().home() / 'Desktop'

# %%
nature_dir = DESKTOP / 'natural_images'

# %%
def extract_images_and_labels(directory):
    all_images = []
    all_labels = []
    
    for folder in directory.iterdir():
        if not folder.is_dir():
            continue
        images = [str(path) for path in folder.glob('*')]
        all_images.extend(images)
        all_labels.extend([folder.name] * len(images))
        
    return all_images, all_labels

# %%
all_images, all_labels = extract_images_and_labels(nature_dir)

print('# images: ', len(all_images))
print('# labels: ', len(all_labels))
print(all_images[0])
print(all_labels[0])
# Out:
# # images:  6899
# # labels:  6899
# C:\Users\a1056968\Desktop\natural_images\airplane\airplane_0000.jpg
# airplane

# %%
labels_dict = {el.name: i for i, el in enumerate(nature_dir.iterdir())}
labels_dict
# Out:
# {'airplane': 0,
#  'car': 1,
#  'cat': 2,
#  'dog': 3,
#  'flower': 4,
#  'fruit': 5,
#  'motorbike': 6,
#  'person': 7}

# %%
all_label_ids = [labels_dict[l] for l in all_labels]

# %%
pd.DataFrame({
    'image_path': all_images,
    'labels': all_labels,
    'label_ids': all_label_ids,
}).sample(5)
# Out:
#                                              image_path     labels  label_ids
# 5866  C:\Users\a1056968\Desktop\natural_images\motor...  motorbike          6
# 2757  C:\Users\a1056968\Desktop\natural_images\dog\d...        dog          3
# 4463  C:\Users\a1056968\Desktop\natural_images\fruit...      fruit          5
# 3283  C:\Users\a1056968\Desktop\natural_images\flowe...     flower          4
# 2211  C:\Users\a1056968\Desktop\natural_images\cat\c...        cat          2

# %% [markdown]
# ### Load images using `ImageDataGenerator()`

# %%
generator = ImageDataGenerator()

# %%
images= generator.flow_from_directory(nature_dir)
# Out:
# Found 6899 images belonging to 8 classes.

# %%
next_batch = images.__next__()

# %% [markdown]
# ### Pipeline using `Dataset()`

# %% [markdown]
# #### Example 1

# %%
dataset = tf.data.Dataset.from_tensor_slices([1, 2, 3])
dataset
# Out:
# <TensorSliceDataset element_spec=TensorSpec(shape=(), dtype=tf.int32, name=None)>

# %%
for el in dataset:
    print(type(el))
    print(el.numpy())
# Out:
# <class 'tensorflow.python.framework.ops.EagerTensor'>
# 1
# <class 'tensorflow.python.framework.ops.EagerTensor'>
# 2
# <class 'tensorflow.python.framework.ops.EagerTensor'>
# 3

# %% [markdown]
# #### Example 2

# %%
dataset = tf.data.Dataset.from_tensor_slices(all_images)

# %%
for el in dataset.take(5):
    print(el)
# Out:
# tf.Tensor(b'C:\\Users\\a1056968\\Desktop\\natural_images\\airplane\\airplane_0000.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\a1056968\\Desktop\\natural_images\\airplane\\airplane_0001.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\a1056968\\Desktop\\natural_images\\airplane\\airplane_0002.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\a1056968\\Desktop\\natural_images\\airplane\\airplane_0003.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\a1056968\\Desktop\\natural_images\\airplane\\airplane_0004.jpg', shape=(), dtype=string)

# %% [markdown]
# #### Initial

# %%
dataset = tf.data.Dataset.from_tensor_slices((all_images, all_label_ids))

# %%
for img, l in dataset.take(2):
    print(img.numpy(), l.numpy())
# Out:
# b'C:\\Users\\a1056968\\Desktop\\natural_images\\airplane\\airplane_0000.jpg' 0
# b'C:\\Users\\a1056968\\Desktop\\natural_images\\airplane\\airplane_0001.jpg' 0

# %% [markdown]
# #### Map

# %% [markdown]
# #### Heading

# %%
def read_image(filename, label):
    return (filename, label)

# %%
dataset = tf.data.Dataset \
    .from_tensor_slices((all_images, all_label_ids)) \
    .map(read_image)

# %%
for img, l in dataset.take(2):
    print(img.numpy(), l.numpy())
# Out:
# [[[0.87058824 0.9372549  0.8980392 ]
#   [0.87159926 0.9382659  0.89905024]
#   [0.8745098  0.9411765  0.9019608 ]
#   ...
#   [0.8        0.8509804  0.8235294 ]
#   [0.80291057 0.85389096 0.82644   ]
#   [0.79675245 0.84773284 0.82028186]]
#
#  [[0.8701593  0.936826   0.8976103 ]
#   [0.87117034 0.937837   0.8986213 ]
#   [0.8740809  0.94074756 0.9015319 ]
#   ...
#   [0.80006033 0.85134566 0.8244476 ]
#   [0.80206615 0.85326767 0.8258167 ]
#   [0.7962498  0.8480143  0.8205633 ]]
#
#  [[0.86856616 0.9352328  0.89601713]
#   [0.86957717 0.93624383 0.89702815]
#   [0.8724877  0.9391544  0.8999387 ]
#   ...
#   [0.8002844  0.8527023  0.8278579 ]
#   [0.79892963 0.8509526  0.82350165]
#   [0.79438287 0.8490598  0.82160884]]
#
#  ...
#
#  [[0.5217735  0.44334215 0.3492245 ]
#   [0.47206074 0.39565143 0.30355585]
#   [0.40148017 0.33089194 0.24461742]
#   ...
#   [0.5336397  0.4356005  0.34932598]
#   [0.5398294  0.44179016 0.35551566]
#   [0.535488   0.43744877 0.35117427]]
#
#  [[0.5307847  0.45235333 0.3582357 ]
#   [0.4736041  0.3971948  0.30509922]
#   [0.39007926 0.31949103 0.23321652]
#   ...
#   [0.5400123  0.44197303 0.35569853]
#   [0.54856676 0.45052755 0.36425304]
#   [0.5435906  0.44555137 0.35927686]]
#
#  [[0.5332108  0.45477942 0.36066177]
#   [0.47401962 0.3976103  0.30551472]
#   [0.3870098  0.31642157 0.23014706]
#   ...
#   [0.54172796 0.44368872 0.35741422]
#   [0.5509191  0.4528799  0.3666054 ]
#   [0.5457721  0.44773284 0.36145833]]] 0
# [[[0.99584866 0.9801624  0.87428004]
#   [0.9907782  0.9764706  0.8733456 ]
#   [0.9843137  0.9764706  0.8862745 ]
#   ...
#   [0.8039216  0.7607843  0.63529414]
#   [0.80068934 0.7575521  0.6320619 ]
#   [0.8        0.75686276 0.6313726 ]]
#
#  [[0.99584866 0.9801624  0.87428004]
#   [0.9907782  0.9764706  0.8733456 ]
#   [0.9846862  0.9762843  0.8862745 ]
#   ...
#   [0.8039216  0.7607843  0.63529414]
#   [0.80068934 0.7575521  0.6320619 ]
#   [0.8        0.75686276 0.6313726 ]]
#
#  [[0.99584866 0.9801624  0.87428004]
#   [0.9907782  0.9764706  0.8733456 ]
#   [0.9857005  0.9757772  0.8862745 ]
#   ...
#   [0.8039216  0.7607843  0.63529414]
#   [0.80068934 0.7575521  0.6320619 ]
#   [0.8        0.75686276 0.6313726 ]]
#
#  ...
#
#  [[0.9996315  0.97837776 0.9054228 ]
#   [0.9937117  0.9709942  0.8980392 ]
#   [0.9948606  0.97214305 0.8991881 ]
#   ...
#   [0.773292   0.74273133 0.62589616]
#   [0.77591187 0.7414498  0.62461466]
#   [0.7705507  0.7352566  0.6110379 ]]
#
#  [[0.999733   0.9766468  0.9054228 ]
#   [0.9954427  0.9692632  0.8980392 ]
#   [0.99659157 0.9704121  0.8991881 ]
#   ...
#   [0.778485   0.7444623  0.6241652 ]
#   [0.7768247  0.74175406 0.6214569 ]
#   [0.7721803  0.7368862  0.6092055 ]]
#
#  [[0.9997702  0.97601104 0.9054228 ]
#   [0.99607843 0.96862745 0.8980392 ]
#   [0.9972273  0.96977633 0.8991881 ]
#   ...
#   [0.78039217 0.74509805 0.62352943]
#   [0.7771599  0.7418658  0.6202972 ]
#   [0.7727788  0.7374847  0.6085325 ]]] 0

# %% [markdown]
# #### Read file

# %%
def read_image(filename, label):
    image = tf.io.read_file(filename)
    return (image, label)

# %%
dataset = tf.data.Dataset \
    .from_tensor_slices((all_images, all_label_ids)) \
    .map(read_image)

# %%
for img, l in dataset.take(1):
    print(img.numpy(), l.numpy())
    pass
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xff\xc0\x00\x11\x08\x00h\x01,\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfd\xa7e\x9e&\n\xd01\x1e\xf4\xac\xa3q"\x15\x00.y\x1c\xd5\xfb\x8dE\\\xe1c\x07\x1cdw\xaa\xeb\x18\xbe\xb8\xdes\x19\x03\x18=\rr\xf3H\xf1ybx\x9f\xed[\xfbPi_\xb3\xfd\x94\x1e\x1d\x8e\xc6\xe4k\xba\xce\x9f%\xd6\x97r\x96\xe1\xa0\x89\x17\x82[-\x92s\xd8\n\xf9\x03R\xfd\xb6\x7fh\xadE\xc4\xd2|\\\x807\x96p"\xd3\x0cJI\xeas\xc1?\x8d}\xe9\xf1\xbf\xf6Y\xf8\x1d\xf1\xf6\xde\xd8|_\xf0D:\xc4\x96\x11\xc8\x9a|\xadq$O\x06\xf0O\xca\xf1\xb2\xb0\xe7\xde\xbf3<c\xfb=|&\xf0\x17\x8f\xb5\x9f\x0c[x{]+\xa7\xea\xf7\x10\x91?\x8e/\xf8Ee\xdb\x81\xbf\x81\xf3\x1e9\xed_\x97\xf1\x8e\x1f<\x85_iF\xab\x84<\x99\xf4\xf9K\xc2B\x95\xa7\x14\xd9\xd3x\x17\xf6\xa4\xf8\xe1\xe1\x8b\xd2u\x7f\x8bz\x9f\xd9\xee.\xfe\xd1sq\x02\xbc\x8c>}\xb8X\xc1R\xdc\x9f^k\xec/\x87\xde<\xf1\xb5\x94W\x1a\x9f\x8a~!\xd8\xea\xda}\xacp\xb3\xde\xddh\xf2\xc3<24-<\x89"\x19\x0e\nF\x84\x9c\xf75\xf0Kx{F\xd1u\x18/\xbc/\xa6Mc%\xbb\xab\xc7$\x9a\x83\xdd>\xe0s\xff\x00-Kdg\x9ek\xb6\xd0\xbe3|Q\xd3\x9fY\xb2\x83\xc5\x97P\xaf\x88\x04\xb2\xeb&R\xad\xf6\x96\x99\n\xca\xd8#\xe5%\t\\.08\x15\xf2\xf96m\x9c\xe0\xe7z\x93\xe6\xf5g}xaj-\x12?L\xb4\x1f\x14\xdax\xab\xc3\xd6\xba\xce\x8b{\x13\xc1y\n\xbd\xbc\xdb8?($\x1cw\xaa:\xc4s_\xc5\xb9\x1d\x02\xfa\xe3\x9a\xf8\xd7\xf6m\xfd\xaft\xef\x82\xfe\x12o\x06\xeb\x177:\xbd\xa26l7H\x15\xe1\xc7\\\xb1\xe0\x8f\xc2\xbd\xcf\xe0\x7f\xedI\xe1_\x8f\x1a\xbe\xab\xa4hzM\xcd\xbb\xe9\x96\x894\x92<\xca\xe8\xfb\x9aA\xd5\x7f\xdd\x1f\x99\xaf\xd5\xb2\x8c\xf2\x9e=(7\xef\x1f5\x8d\xa3R/\x9a/C\xbfm&`\xc0\x0b\x9e\x0f\xbd[\xb2\xd3\\q$\xc0\x91\xd0SbC<\xa5\x9f\x80\xa7\x1f-[D\x89\x18:H=\xb2k\xe8\xe7\xa2<\xf8F2z\x96\xb4\xfbi\xa0\xfb\xae\x83\xd7\x8a\x92\xfe;\xa9\xe2\xf2\x83\x8cz\x8aj\xc8\xfbC\r\x8d\x91\x9c.i\xe9v\xa3\x87V\x1e\xc0\xd6vGZ\x8cm\xb1\xcej\xbe\x13\xbc\xbao6\x05\xf9\xb1\xc9=\xeb,\xf8?R\x04\x86\x99\x01\x1dF\xd3]\xa4\x971\x87\xc6\xf6@z\x165\x1c\xf3yn<\xb9U\xd4\xf5\xc0\xe6\xab\x9aF~\xca\x1d\xceI|\x1f~\xc0\x07\x95q\xea*+\x8f\x06\xcf\x0c\x8b\xba\xec`\xf6\xc7J\xea/\xae\x84\r\xb9\xca\xe0\xf3\xefY\xb7\xfa\x96\xd9\x15\xe3r\xcb\x8e\xf5>\xd6}\x83\xd8\xc3\xb9\x8e\xde\x15|\x16\xfbP\x18\xe9\x81P7\x87<\x96%\xae\t\x1 ...

# %% [markdown]
# #### Decode bytes

# %%
def read_image(filename, label):
    image_bytes = tf.io.read_file(filename)
    image_data = tf.image.decode_jpeg(image_bytes)
    return (image_data, label)

# %%
dataset = tf.data.Dataset \
    .from_tensor_slices((all_images, all_label_ids)) \
    .map(read_image)

# %%
for img, l in dataset.take(1):
    print(img.numpy(), l.numpy())
# Out:
# [[[222 239 229]
#   [222 239 229]
#   [223 240 230]
#   ...
#   [204 217 210]
#   [205 218 211]
#   [203 216 209]]
#
#  [[221 238 228]
#   [221 238 228]
#   [222 239 229]
#   ...
#   [205 220 213]
#   [202 215 208]
#   [202 217 210]]
#
#  [[221 238 228]
#   [221 238 228]
#   [222 239 229]
#   ...
#   [197 214 208]
#   [202 217 210]
#   [201 218 210]]
#
#  ...
#
#  [[148 128 104]
#   [147 127 103]
#   [145 127 103]
#   ...
#   [124  99  77]
#   [124  99  77]
#   [123  98  76]]
#
#  [[131 111  87]
#   [123 103  79]
#   [111  93  71]
#   ...
#   [135 110  88]
#   [135 110  88]
#   [134 109  87]]
#
#  [[137 117  93]
#   [125 105  81]
#   [109  91  69]
#   ...
#   [139 114  92]
#   [141 116  94]
#   [139 114  92]]] 0

# %% [markdown]
# #### Scale

# %%
def read_image(filename, label):
    image_bytes = tf.io.read_file(filename)
    image_data = tf.image.decode_jpeg(image_bytes)
    image_scaled = tf.cast(image_data, float) / 255.0
    
    return (image_scaled, label)

# %%
dataset = tf.data.Dataset \
    .from_tensor_slices((all_images, all_label_ids)) \
    .map(read_image)

# %%
for img, l in dataset.take(1):
    print(img.numpy().shape, l.numpy().shape)
# Out:
# (104, 300, 3) ()

# %% [markdown]
# #### Resize

# %%
IMAGE_SIZE = (256, 256)
IMAGE_SIZE_WITH_CHANNELS = (256, 256, 3)

# %%
def read_image(filename, label):
    image_bytes = tf.io.read_file(filename)
    image_data = tf.image.decode_jpeg(image_bytes)
    image_scaled = tf.cast(image_data, float) / 255.0
    image_resized = tf.image.resize(image_scaled, IMAGE_SIZE)
    
    return (image_resized, label)

# %%
dataset = tf.data.Dataset \
    .from_tensor_slices((all_images, all_label_ids)) \
    .map(read_image) \
    .batch(4)

# %%
for img, l in dataset.take(1):
    print(img.numpy().shape, l.numpy().shape)
# Out:
# (4, 256, 256, 3) (4,)

# %% [markdown]
# #### Batch

# %%
dataset = tf.data.Dataset \
    .from_tensor_slices((all_images, all_label_ids)) \
    .shuffle(len(all_images)) \
    .map(read_image) \
    .batch(4)

# %%
for img, l in dataset.take(1):
    print(img.numpy().shape, l.numpy().shape)
# Out:
# (4, 256, 256, 3) (4,)

# %% [markdown]
# #### Model

# %%
n_labels = len(labels_dict)

model = Sequential([
    Input(shape=IMAGE_SIZE_WITH_CHANNELS),
    
    Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu'),
    Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(),
    Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='relu'),
    Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(),
    Conv2D(filters=8, kernel_size=(3, 3), padding='same', activation='relu'),
    Conv2D(filters=8, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPool2D(),
    
    Dense(32, activation='relu'),
    Dense(n_labels, activation = 'softmax'),
])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 256, 256, 32)      896
#
#  conv2d_19 (Conv2D)          (None, 256, 256, 32)      9248
#
#  max_pooling2d_9 (MaxPooling  (None, 128, 128, 32)     0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 128, 128, 16)      4624
#
#  conv2d_21 (Conv2D)          (None, 128, 128, 16)      2320
#
#  max_pooling2d_10 (MaxPoolin  (None, 64, 64, 16)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 8)         1160
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 8)         584
#
#  max_pooling2d_11 (MaxPoolin  (None, 32, 32, 8)        0
#  g2D)
#
#  dense_6 (Dense)             (None, 32, 32, 32)        288
#
#  dense_7 (Dense)             (None, 32, 32, 8)         264
#
# =================================================================
# Total params: 19,384
# Trainable params: 19,384
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Repeat

# %%
dataset = tf.data.Dataset \
    .from_tensor_slices((all_images, all_label_ids)) \
    .shuffle(len(all_images)) \
    .map(read_image) \
    .batch(4) \
    .repeat()

# %% [markdown]
# #### Compile and train

# %%
dataset.element_spec
# Out:
# (TensorSpec(shape=(None, 256, 256, None), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None,), dtype=tf.int32, name=None))

# %%
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = 'adam')

# %%
# TODO
# model.fit(dataset, epochs=10, steps_per_epoch=len(all_images) // 4)
