# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from skimage.io import imread

import helper_functions as hp

# %% [markdown]
# # Image channels

# %% [markdown]
# ### Reading an image

# %%
lion = imread('https://static.posters.cz/image/750/posters/african-lion-i8112.jpg')

# %%
hp.print_image(lion)

# %%
channels = [lion[:,:,0], lion[:,:,1], lion[:,:,2]]

hp.print_images(channels, names=['R', 'G', 'B'])

# %%
hp.describe_image(lion)
# Out:
# min: 0.00
# max: 255.00
# shape: (709, 473, 3)
