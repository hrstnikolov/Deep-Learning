# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pathlib import Path

# %% [markdown]
# # Emails

# %% [markdown]
# ## Heading

# %%
inbox_path = Path().home() / "Desktop//inbox.CSV"
inbox = pd.read_csv(inbox_path, encoding='ISO-8859-1')
inbox
# Out:
#                                            ï»¿"Subject"  \
# 0               Project RAPA: CR of the safety analyses
# 1     Learning Reminder: 2022 Global Privacy & Infor...
# 2           Learning Reminder: 2022 Global Anti-Bribery
# 3                                       RE: ISO11410107
# 4               RE: PRJ13300 RAPA internal team meeting
# ...                                                 ...
# 2610                      FW: No responses to documents
# 2611  WG: Deckblatt Drucksensor 17998001 Index 1 Sen...
# 2612  RE: No responses to documents -Continental Sup...
# 2613   ð£ ÐÐµÐ»Ð¸ÐºÐ´ÐµÑÐºÐ¸ ÐÐ°Ð·Ð°Ñ ð£_06....
# 2614  For Your Information: Timecard (20-MAR-2023 to...
#
#                                                    Body  \
# 0     Hello,\r\n\r\n \r\n\r\nI had an action item on...
# 1     Hi Hristo Lyubomirov Nikolov (Ð¥ÑÐ¸ÑÑÐ¾ ÐÑ...
# 2     Hi Hristo Lyubomirov Nikolov (Ð¥ÑÐ¸ÑÑÐ¾ ÐÑ...
# 3     All,\r\n\r\n \r\n\r\n@Nikolov, Hristo <mailto:...
# ...

# %%
# sent_mails_path = Path().home() / "Desktop//sent_mails.CSV"
# sent_mails = pd.read_csv(sent_mails_path, encoding='ISO-8859-1')
# sent_mails

# %%
inbox
# Out:
#                                            ï»¿"Subject"  \
# 0               Project RAPA: CR of the safety analyses
# 1     Learning Reminder: 2022 Global Privacy & Infor...
# 2           Learning Reminder: 2022 Global Anti-Bribery
# 3                                       RE: ISO11410107
# 4               RE: PRJ13300 RAPA internal team meeting
# ...                                                 ...
# 2610                      FW: No responses to documents
# 2611  WG: Deckblatt Drucksensor 17998001 Index 1 Sen...
# 2612  RE: No responses to documents -Continental Sup...
# 2613   ð£ ÐÐµÐ»Ð¸ÐºÐ´ÐµÑÐºÐ¸ ÐÐ°Ð·Ð°Ñ ð£_06....
# 2614  For Your Information: Timecard (20-MAR-2023 to...
#
#                                                    Body  \
# 0     Hello,\r\n\r\n \r\n\r\nI had an action item on...
# 1     Hi Hristo Lyubomirov Nikolov (Ð¥ÑÐ¸ÑÑÐ¾ ÐÑ...
# 2     Hi Hristo Lyubomirov Nikolov (Ð¥ÑÐ¸ÑÑÐ¾ ÐÑ...
# 3     All,\r\n\r\n \r\n\r\n@Nikolov, Hristo <mailto:...
# ...
